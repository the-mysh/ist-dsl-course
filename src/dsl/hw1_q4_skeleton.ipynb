# %% [markdown]
# # LLM pretraining

# %% [markdown]
# In this notebook, we will explore the process of pretraining a large language model (LLM) from scratch, focusing on a decoder-only transformer architecture.
#
# The vast majority of current LLMs are trained with a causal auto-regressive objective, where the model predicts the next token given the previous tokens.
#
# We will follow this approach to train a character-level LLM on the works of Shakespeare.

# %%
import dataclasses
import math
import random
import torch
import torch.cuda
import torch.nn as nn
import torch.nn.functional as F
import torch.optim
import torch.utils.data
import time
import matplotlib.pyplot as plt
import numpy as np
from typing import Optional


plt.style.use('seaborn-v0_8')

# %% [markdown]
# ## Part I: The training data

# %% [markdown]
# We will start by preparing the data to train the model, available at [https://raw.githubusercontent.com/karpathy/char-rnn/master/data/tinyshakespeare/input.txt
# ](https://raw.githubusercontent.com/karpathy/char-rnn/master/data/tinyshakespeare/input.txt
# ).
#
# This data was originally used in the following [blog post](https://karpathy.github.io/2015/05/21/rnn-effectiveness/), also worth reading.

# %%
# Downloading the tiny shakespeare dataset
# !wget https://raw.githubusercontent.com/karpathy/char-rnn/master/data/tinyshakespeare/input.txt

# read it in to inspect it
with open('input.txt', 'r', encoding='utf-8') as f:
    text = f.read()

print("Length in characters: ", len(text))

# let's look at the first 100 characters
print("First 100 characters", "-" * 50)
print(text[:100])
# Out:
# --2026-05-15 15:12:25--  https://raw.githubusercontent.com/karpathy/char-rnn/master/data/tinyshakespeare/input.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1115394 (1.1M) [text/plain]
# Saving to: ‘input.txt’
#
# input.txt           100%[===================>]   1.06M  --.-KB/s    in 0.01s
#
# 2026-05-15 15:12:25 (72.6 MB/s) - ‘input.txt’ saved [1115394/1115394]
#
# Length in characters:  1115394
# First 100 characters --------------------------------------------------
# First Citizen:
# Before we proceed any further, hear me speak.
#
# All:
# Speak, speak.
#
# First Citizen:
# You

# %% [markdown]
# From here, we can create the model vocabulary, which maps the characters into token ids.
#
# We can train the vocabulary on the whole training set and perform some light testing to check that everything is working as expected.

# %%
class Vocabulary:
  """Character-level vocabulary"""

  def __init__(self, text: str):
    """Initialize the vocabulary, mapping individual characters to integers."""
    # We create two dictionaries, ctoi and itoc: the former mapping characters
    # to unique integers and the latter with the reverse mapping.
    chars = set(text)
    self.ctoi = {c: i for i, c in enumerate(chars)}
    self.itoc = {v: k for k, v in self.ctoi.items()}

  def encode(self, text: str) -> list[int]:
    """Encode a string as a list of token ids."""
    return [self.ctoi[t] for t in text]

  def decode(self, ids: list[int]) -> str:
    """Decode a list of token ids into a string."""
    return "".join(self.itoc[i] for i in ids)

  def __len__(self):
    return len(self.ctoi)

  def __str__(self):
    return f"Vocabulary[size={len(self)}]{self.ctoi}"

vocab = Vocabulary(text)
print(vocab)

# Test if encoding/decoding work
first_chars = text[:1000]
encoded = vocab.encode(first_chars)
decoded = vocab.decode(encoded)
assert first_chars == decoded
# Out:
# Vocabulary[size=65]{':': 0, '3': 1, 'k': 2, 'n': 3, 'j': 4, '.': 5, 'T': 6, '&': 7, 'z': 8, 'H': 9, ' ': 10, '$': 11, "'": 12, 'X': 13, 'Y': 14, 'I': 15, 'Q': 16, 'D': 17, 'A': 18, 'a': 19, 'y': 20, 'N': 21, ',': 22, 'E': 23, 'p': 24, 'x': 25, 'J': 26, 'd': 27, 'r': 28, 'f': 29, '?': 30, 'R': 31, 'e': 32, 'q': 33, 'i': 34, 'L': 35, ';': 36, 'Z': 37, 'O': 38, 'w': 39, 'C': 40, 'F': 41, 'm': 42, '-': 43, '!': 44, 'l': 45, '\n': 46, 'o': 47, 'S': 48, 'b': 49, 'G': 50, 'K': 51, 'P': 52, 'V': 53, 'M': 54, 'U': 55, 't': 56, 'u': 57, 'h': 58, 'W': 59, 'c': 60, 'v': 61, 'B': 62, 's': 63, 'g': 64}

# %% [markdown]
# With our vocabulary, we can encode the full text data as a tensor and split it into data for training and validation.

# %%
# Encode all text
encoded_text = torch.tensor(vocab.encode(text))
print("Total tokens:", encoded_text.size(0))
# Split into train and validation
val_size = 2000

encoded_train = encoded_text[:-val_size]
encoded_val = encoded_text[-val_size:]
print("Train tokens:", encoded_train.size(0))
print("Val tokens: ", encoded_val.size(0))
# Out:
# Total tokens: 1115394
# Train tokens: 1113394
# Val tokens:  2000

# %% [markdown]
# From here, we can create the dataset class to iterate the data. Each record will be a chunk of adjacent tokens and the model will learn to predict the next token from the previous ones.
#
# We will train on sequences of 512 tokens, which offers a good trade-off between previous context length and efficiency (due to the quadractic behavior of attention).

# %%
# Predict on block_size contiguous tokens
seq_len = 512


class ShakespeareDataset(torch.utils.data.Dataset):
  """Dataset class return input and target ids for a given idx"""

  def __init__(self, data: torch.Tensor, seq_len: int):
    self.data = data
    self.seq_len = seq_len


  def __getitem__(self, i: int) -> torch.Tensor:
    """Selects the seq_len+1 tokens starting at index i for training.

    Returns:
        (x, y) tuple, with the input and target ids.
    """
    # Account for extra one in LM offset
    data = self.data[i:i + self.seq_len + 1]
    x = data[:-1]
    y = data[1:]
    return x, y

  def __len__(self):
    """The length of the dataset, only considering complete sequences."""
    return len(self.data) - self.seq_len - 1

train = ShakespeareDataset(encoded_train, seq_len)
val = ShakespeareDataset(encoded_val, seq_len)
print("Train size:", len(train), ", val size:", len(val))
# Out:
# Train size: 1112881 , val size: 1487

# %% [markdown]
# ## Part II: The Transformer Model

# %% [markdown]
# In this section of the notebook, we will implement a standard decoder-only transformer model.
#
# There are many flavours of the transformer architecture, varying all components of the transformer network. In this notebook, we will consider the following configuration:
#
# * **Learnt Positional Encoddings** - In conjuntion with sinosoidal embeddings, these are one of the first approaches for encoding positional information in the transformer architecture, by learning position vectors to encode this information. Currently, however, most transformers adopt [RoPE embeddings](https://arxiv.org/abs/2104.09864).
#
# * **Pre layer normalization** - In contrast with the original transformer, we will add layer normalization *before* the attention and mlp blocks, which is shown to improve performance. Nevertheless, we will adopt the original layer normalization instead of the, nowadays more common, [RMS normalization](https://arxiv.org/abs/1910.07467).
#
# * **MLP with gelu activation** - Following the original transformer, we adopt a two layer MLP, but replace the ReLU activation with [GeLU](https://arxiv.org/abs/1606.08415). Recently, larger models also successfuly adopted variations of [GLUs](https://arxiv.org/abs/2002.05202).
#
# We start by defining the model configuration.

# %%
@dataclasses.dataclass
class Config:
  seq_len: int = seq_len
  n_layers: int = 2
  n_heads: int = 1
  hidden_size: int = 64
  ffn_hidden_size: int = None  # set in __post_init__ if not specified
  head_size: int = None  # as above
  vocab_size: int = len(vocab)

  def __post_init__(self):
    # Using the ffn hidden size as 4 times the
    # network hidden size is a standard value.
    if self.ffn_hidden_size is None:
      self.ffn_hidden_size: int = self.hidden_size * 4

    # Using a head size of hidden_size // n_heads
    # is also a standard approach.
    if self.head_size is None:
      self.head_size = self.hidden_size // self.n_heads

# default configuration
default_config = Config()
print(default_config)
# Out:
# Config(seq_len=512, n_layers=2, n_heads=1, hidden_size=64, ffn_hidden_size=256, head_size=64, vocab_size=65)

# %%
# multi-head configuration
mh_config = Config(n_heads=6, hidden_size=384)
print(mh_config)
# Out:
# Config(seq_len=512, n_layers=2, n_heads=6, hidden_size=384, ffn_hidden_size=1536, head_size=64, vocab_size=65)

# %% [markdown]
# Afterwards, we will define the self-attention mechanism.

# %%
class SingleHeadAttention(nn.Module):

  def __init__(self, config: Config):
    super().__init__()
    self.config = config
    # As is common in most transformer implementations, we will have single projection
    # matrices to compute queries, keys and values for all heads.
    # As such, each projection matrix will map an input of hidden_size to an output
    # of n_heads * head_size.

    if config.n_heads > 1:
      raise ValueError(f"{self.__class__.__name__} only implements single-head attention; config specifies {config.n_heads} heads")

    self.queries_proj = nn.Linear(config.hidden_size, config.head_size)
    self.keys_proj = nn.Linear(config.hidden_size, config.head_size)
    self.values_proj = nn.Linear(config.hidden_size, config.head_size)
    self.out_proj = nn.Linear(config.head_size, config.hidden_size)

  def forward(self, x: torch.Tensor) -> torch.Tensor:
    # x shape: (batch, seq, hidden)
    B, T, _ = x.size()
    head_dim = self.config.head_size

    # Compute projections and split by queries, keys and values.
    # q, k, v shapes: (batch, seq, head_size).
    q, k, v = self.queries_proj(x), self.keys_proj(x), self.values_proj(x)

    # Isolate heads
    # q, k, v shapes: (batch, seq, head_size)
    q = q.view(B, T, head_dim)
    k = k.view(B, T, head_dim)
    v = v.view(B, T, head_dim)

    # Compute scaled dot product attention.
    # out shape: (batch, seq, head_size)
    scores = (q @ k.transpose(-2, -1)) * (1.0 / math.sqrt(k.size(-1)))
    causal_mask = torch.tril(torch.ones(T, T, device=scores.device))
    causal_mask = causal_mask.view(1, T, T)
    scores = scores.masked_fill(causal_mask == 0, float("-inf"))
    attn = F.softmax(scores, dim=-1)
    out = attn @ v

    # Compute the final projection
    # out shape: (batch, seq, hidden_size)
    out = self.out_proj(out)
    return out

# %%
# Q4.2
class MultiHeadAttention(nn.Module):
  def __init__(self, config: Config):
    super().__init__()
    self.config = config

    # hidden size is expected to be the same as n heads * head size, but in principle could be different
    dim = (config.hidden_size, config.n_heads * config.head_size)
    self.queries_proj = nn.Linear(*dim)
    self.keys_proj = nn.Linear(*dim)
    self.values_proj = nn.Linear(*dim)
    self.out_proj = nn.Linear(*dim[::-1])

  def forward(self, x: torch.Tensor) -> torch.Tensor:
    # x shape: (batch, seq, hidden)
    B, T, _ = x.size()

    # Compute projections and split by queries, keys and values.
    # q, k, v shapes: <batch size, seq length, n heads * head size>
    q, k, v = self.queries_proj(x), self.keys_proj(x), self.values_proj(x)

    # Isolate heads
    # <batch size, seq length, n heads * head size> -> <batch size, seq length, n heads, head size>
    dim = (B, T, self.config.n_heads, self.config.head_size)
    q = q.view(*dim)
    k = k.view(*dim)
    v = v.view(*dim)

    # Transpose to perform multiplications for each head independently
    # (swap seq length and n heads)
    # <batch size, seq length, n heads, head size> -> <batch size, n heads, seq length, head size>
    q = q.transpose(1, 2)
    k = k.transpose(1, 2)
    v = v.transpose(1, 2)

    # Compute scaled dot product attention
    scores = (q @ k.transpose(-2, -1)) * (1.0 / math.sqrt(k.size(-1)))  # -> <batch size, n heads, seq length, seq length>
    causal_mask = torch.tril(torch.ones(T, T, device=scores.device))
    causal_mask = causal_mask.view(1, 1, T, T)  # one more neutral dimension
    scores = scores.masked_fill(causal_mask == 0, float("-inf"))
    attn = F.softmax(scores, dim=-1)
    out = attn @ v  # -> <batch size, n heads, seq length, head size>

    # Concatenate heads
    out = out.transpose(1, 2)  # back to <batch size, seq length, n heads, head size>
    out = out.contiguous().view(B, T, -1)  # -> <batch size, seq length, n heads * head size>

    # Final projection
    out = self.out_proj(out)  # -> <batch size, seq length, hidden size>
    return out

# %% [markdown]
# Second, we will define the MLP layer of the transformer. In our implementation, we will adopt:
# * Up projection layer mapping hidden_size to ffn_hidden_size;
# * Activation function (GeLU);
# * Down projection layer mapping ffn_hidden_size to hidden_size;
# * Dropout.

# %%
class MLP(nn.Module):

  def __init__(self, config: Config):
    super().__init__()
    self.up_proj = nn.Linear(config.hidden_size, config.ffn_hidden_size)
    self.act = nn.GELU()
    self.down_proj = nn.Linear(config.ffn_hidden_size, config.hidden_size)

  def forward(self, x: torch.Tensor) -> torch.Tensor:
    x = self.up_proj(x)
    x = self.act(x)
    x = self.down_proj(x)
    return x

# %% [markdown]
# Now, we will define the transformer block. In contrast with the original transformer implementation, we will apply layer normalization before self-attention and the MLP.

# %%
class Block(nn.Module):

  def __init__(self, config: Config):
    super().__init__()
    attn_class = SingleHeadAttention if config.n_heads == 1 else MultiHeadAttention
    self.attn = attn_class(config)
    self.attn_norm = nn.LayerNorm(config.hidden_size)
    self.mlp = MLP(config)
    self.mlp_norm = nn.LayerNorm(config.hidden_size)

  def forward(self, x: torch.Tensor) -> torch.Tensor:
    h = self.attn_norm(x)
    h = self.attn(h)
    x = x + h
    h = self.mlp_norm(x)
    h = self.mlp(h)
    x = x + h
    return x

# %% [markdown]
# Finally, we will define the transformer decoder, using a causal language modeling objective. For this example, we use learnt embeddings to represent positional information in the transformer.

# %%
class Transformer(nn.Module):

  def __init__(self, config: Config):
    super().__init__()
    # Initialize both embedding layers, one with the size of the vocabulary,
    # and another with the size of the sequence length.
    self.tok_emb = nn.Embedding(config.vocab_size, config.hidden_size)
    self.pos_emb = nn.Embedding(config.seq_len, config.hidden_size)
    # Initialize the transformer blocks
    self.blocks = nn.ModuleList(Block(config) for _ in range(config.n_layers))
    # It is also common to add a final layer norm before the lm_head
    self.final_norm = nn.LayerNorm(config.hidden_size)
    self.lm_head = nn.Linear(config.hidden_size, config.vocab_size, bias=False)

  def forward(
      self,
      inputs: torch.Tensor,
      *,
      labels: Optional[torch.Tensor] = None
  ) -> tuple[torch.Tensor, Optional[torch.Tensor]]:
    """Computes the forward of a transformer model.

    Returns a tuple with two elements. The first is the final logits,
    and the second is the loss (only when labels are provided)
    """
    tok_emb = self.tok_emb(inputs)
    pos_emb = self._get_pos_embeddings(inputs)

    hidden_states = tok_emb + pos_emb

    for block in self.blocks:
      hidden_states = block(hidden_states)

    hidden_states = self.final_norm(hidden_states)
    logits = self.lm_head(hidden_states)

    if labels is None:
      return logits, None

    logits = logits.view(-1, logits.size(-1))
    labels = labels.view(-1)
    loss = F.cross_entropy(logits, labels)
    return logits, loss

  def _get_pos_embeddings(self, tokens: torch.Tensor) -> torch.Tensor:
    """Computes the positional embeddings for the given tokens."""
    batch_size, seq_len = tokens.size()
    pos_idx = torch.arange(seq_len, device=tokens.device)
    pos_emb = self.pos_emb(pos_idx)
    return pos_emb

# %% [markdown]
# ## Part III: Training and Evaluation
#
# In the final part of this notebook, we will implement the training loop, as well as a generation function, and train our transformer.
#
# In order to mitigate expensive cost of training language models, we will implement [mixed precision training](https://arxiv.org/abs/1710.03740). In this approach, while the weights are stored in fp32, the operations inside the model are performed with fp16, levergaging faster gpu implementations.

# %%
def train_step(
    *,
    model: Transformer,
    optimizer: torch.optim.Optimizer,
    scaler: torch.amp.GradScaler,
    device: str,
    x: torch.Tensor,
    y: torch.Tensor,
):
  optimizer.zero_grad()

  # Runs the model in mixed precision, which improves overall speed
  # with minimal performance degradation.
  # https://pytorch.org/docs/stable/notes/amp_examples.html#typical-mixed-precision-training
  with torch.autocast(device_type=device, dtype=torch.float16):
    _, loss = model(x, labels=y)

  scaler.scale(loss).backward()

  scaler.step(optimizer)

  scaler.update()

  return loss.item()

# %%
@torch.no_grad
def validate(
    *,
    model: Transformer,
    val_dataloader: torch.utils.data.DataLoader,
    device: str,
):
    model.eval()
    total_loss = 0.0
    for x, y in val_dataloader:
        x, y = x.to(device), y.to(device)
        with torch.autocast(device_type=device, dtype=torch.float16):
          _, loss = model(x, labels=y)
        total_loss += loss

    total_loss /= len(val_dataloader)

    model.train()
    return total_loss.item()

# %%
@torch.no_grad
def generate(
  model: nn.Module,
  vocab: Vocabulary,
  input: str,
  new_tokens: int,
  device,
):
  model.eval()
  idx = vocab.encode(input)
  idx = torch.tensor(idx, dtype=torch.long, device=device)
  idx = idx.unsqueeze(0)

  for t in range(new_tokens):
    # The model only considers the previous seq len characters.
    ctx = idx[:, -seq_len:]

    with torch.autocast(device_type=device, dtype=torch.float16):
      logits, _ = model(ctx)

    next_logits = logits[:, -1, :]

    next_probs = torch.softmax(next_logits, dim=-1)

    next_idx = torch.multinomial(next_probs, num_samples=1)
    # append sampled index to the running sequence and continue
    idx = torch.cat((idx, next_idx), dim=1)

  idx = idx.tolist()[0]
  output = vocab.decode(idx)
  model.train()
  return output

# %%
def run_validation(
    *,
    model,
    val_dataloader,
    device,
    val_gen_tokens=100):
  val_input = "\n" # Simulate the end of the last paragraph

  val_loss = validate(
      model=model,
      val_dataloader=val_dataloader,
      device=device,
  )
  print("Validation", "-" * 39)
  print(f"Total loss={val_loss:.3f}")
  test_input = "\n" # Continue to use new line as if beginning a new paragraph
  test_gen_len = 200
  test_output = generate(
      model,
      vocab,
      test_input,
      test_gen_len,
      device
  )
  print(test_output)
  print("-" * 50)
  return val_loss

# %%
def set_seed(seed = 42):
  random.seed(seed)
  torch.manual_seed(seed)
  torch.set_float32_matmul_precision("high")

# %%
def train_model(
    *,
    config = Config(),
    num_steps=2000,
    val_every=500,
    log_every=50):

  set_seed()

  device = "cuda" if torch.cuda.is_available() else "cpu"
  if device == "cpu":
    print("WARNING: Using cpu device, training will be slow")

  train_dataloader = torch.utils.data.DataLoader(
      train, batch_size=64, shuffle=True, pin_memory=True, num_workers=2, prefetch_factor=2,
  )
  val_dataloader = torch.utils.data.DataLoader(
      val, batch_size=64, shuffle=False, pin_memory=True, num_workers=2, prefetch_factor=2,
  )

  model = Transformer(config)

  model_params = sum(p.numel() for p in model.parameters())
  print(f"Total parameters: {model_params / 1e6:.2f}M")

  optimizer = torch.optim.AdamW(
      model.parameters(), lr=1e-3, weight_decay=0.1, betas=(0.9, 0.95), fused=True
  )
  scaler = torch.amp.GradScaler()
  model.to(device)

  dataiter = iter(train_dataloader)
  start_time = time.time()
  start_step = time.time()

  train_losses = []
  val_losses = []

  val_losses.append(run_validation(
      model=model,
      val_dataloader=val_dataloader,
      device=device,
  ))

  for step in range(1, num_steps + 1):
    x, y = next(dataiter)
    x, y = x.to(device), y.to(device)
    token_count = x.numel()
    loss = train_step(
        model=model,
        optimizer=optimizer,
        scaler=scaler,
        device=device,
        x=x,
        y=y)

    train_losses.append(loss)

    step_time = time.time() - start_step
    start_step = time.time()
    if step % log_every == 0:
      completed = step / num_steps * 100
      ellapsed = time.time() - start_time
      tok_per_sec = token_count / step_time
      fmt_ellapsed = time.strftime("%H:%M:%S", time.gmtime(ellapsed))
      print(
          f"Step {step}/{num_steps} ({completed:.0f}%): "
          f"TrainTime={fmt_ellapsed}, "
          f"Loss={loss:.3f}, "
          f"StepTime={step_time:.2}s"
      )
    if step % val_every == 0:
      val_losses.append(run_validation(
          model=model,
          val_dataloader=val_dataloader,
          device=device
      ))

  test_input = "\n" # Continue to use new line as if beginning a new paragraph
  test_gen_len = 1000
  test_output = generate(
      model,
      vocab,
      test_input,
      test_gen_len,
      device
  )
  print("Final generation", "-" * 30)
  print(test_output)

  return train_losses, val_losses

# %%
def plot_losses(train_losses, val_losses):
  num_steps = len(train_losses)
  val_every = num_steps // (len(val_losses) - 1)

  fig, ax = plt.subplots(figsize=(12, 5))
  ax.plot(np.arange(num_steps) + 1, train_losses, lw=1.5, label="Training loss")
  ax.plot(np.arange(0, num_steps + 1, val_every) + 1, val_losses, lw=1, ls='--', marker='o', label="Validation loss")
  ax.set_xlabel("Training step")
  ax.set_ylabel("Loss")
  ax.legend()

# %%
t, v = train_model(config=default_config)
plot_losses(t, v)
# Out:
# Total parameters: 0.14M
# Validation ---------------------------------------
# Total loss=4.300
#
# m:Hy3IH$?,;CgQr.LPe&?AY.WZtKmm;?w?dUHxq;HMCsFb,TWkYsOENK;Dr&JZRCBEG?MdvouIzxNDNeHAZUUQhrMruXq-r,zLONFVDsHTME-m,cp?mnrGN;yKDPTDsAoVSJMuNCi
# ewwjlqwMWyzxWTGOSdiAlMlyKh!K FeEPS&y3IfiSJ
# :Aov v&cq.vWdVD
# oF-
# --------------------------------------------------
# Step 50/2000 (2%): TrainTime=00:00:02, Loss=2.882, StepTime=0.025s
# Step 100/2000 (5%): TrainTime=00:00:03, Loss=2.639, StepTime=0.024s
# Step 150/2000 (8%): TrainTime=00:00:04, Loss=2.543, StepTime=0.025s
# Step 200/2000 (10%): TrainTime=00:00:05, Loss=2.489, StepTime=0.024s
# Step 250/2000 (12%): TrainTime=00:00:07, Loss=2.480, StepTime=0.024s
# Step 300/2000 (15%): TrainTime=00:00:08, Loss=2.486, StepTime=0.024s
# Step 350/2000 (18%): TrainTime=00:00:09, Loss=2.471, StepTime=0.024s
# Step 400/2000 (20%): TrainTime=00:00:10, Loss=2.476, StepTime=0.024s
# Step 450/2000 (22%): TrainTime=00:00:11, Loss=2.457, StepTime=0.024s
# Step 500/2000 (25%): TrainTime=00:00:13, Loss=2.449, StepTime=0.024s
# Validation ---------------------------------------
# Total loss=2.516
#
# Tr ave hiv g weswouchad curmy ll he r'lad gs ond ow ensale ba d anthoro favecathadnetyonth gs wit apesassea.
# CESTIOThe sm Mand?
# He oif S:
# Thulaint he buyoo ICOkngse h, t shalond y,-breroty wale d d.
# N
# --------------------------------------------------
# Step 550/2000 (28%): TrainTime=00:00:15, Loss=2.442, StepTime=0.026s
# Step 600/2000 (30%): TrainTime=00:00:16, Loss=2.424, StepTime=0.024s
# Step 650/2000 (32%): TrainTime=00:00:17, Loss=2.439, StepTime=0.024s
# Step 700/2000 (35%): TrainTime=00:00:18, Loss=2.419, StepTime=0.024s
# Step 750/2000 (38%): TrainTime=00:00:20, Loss=2.408, StepTime=0.024s
# Step 800/2000 (40%): TrainTime=00:00:21, Loss=2.390, StepTime=0.024s
# Step 850/2000 (42%): TrainTime=00:00:22, Loss=2.371, StepTime=0.024s
# Step 900/2000 (45%): TrainTime=00:00:23, Loss=2.383, StepTime=0.024s
# Step 950/2000 (48%): TrainTime=00:00:24, Loss=2.361, StepTime=0.024s
# Step 1000/2000 (50%): TrainTime=00:00:26, Loss=2.343, StepTime=0.025s
# Validation ---------------------------------------
# Total loss=2.388
#
# vuted Pave oucan?
# AUETES:
# Qut weseif fenor t tousctheau hoot'ss?
#
# NUCOUM:
# Andu qured t lemasegh orild terat,
# We ce sthamunther shon ced and, wsusersthe t Toramant thanqucy f stitthe
# Anfam n Ris tche's
# --------------------------------------------------
# Step 1050/2000 (52%): TrainTime=00:00:28, Loss=2.325, StepTime=0.025s
# Step 1100/2000 (55%): TrainTime=00:00:29, Loss=2.318, StepTime=0.024s
# Step 1150/2000 (57%): TrainTime=00:00:30, Loss=2.302, StepTime=0.024s
# Step 1200/2000 (60%): TrainTime=00:00:32, Loss=2.291, StepTime=0.024s
# Step 1250/2000 (62%): TrainTime=00:00:33, Loss=2.272, StepTime=0.024s
# Step 1300/2000 (65%): TrainTime=00:00:34, Loss=2.265, StepTime=0.024s
# Step 1350/2000 (68%): TrainTime=00:00:35, Loss=2.238, StepTime=0.024s
# Step 1400/2000 (70%): TrainTime=00:00:36, Loss=2.228, StepTime=0.026s
# Step 1450/2000 (72%): TrainTime=00:00:38, Loss=2.221, StepTime=0.024s
# Step 1500/2000 (75%): TrainTime=00:00:39, Loss=2.209, StepTime=0.026s
# Validation ---------------------------------------
# Total loss=2.236
#
# SPe Buspors yover
# A prorspand, mad nely,
# Cohth thaty:
# Thannden tay as frikis; frioot's, Dare s eplober bansers
# rdaster yot Myou ommpite wnoks tor tive!
# Mon ins urve wait ome; otth hiu I's bliditht,
# I'
# --------------------------------------------------
# Step 1550/2000 (78%): TrainTime=00:00:41, Loss=2.215, StepTime=0.024s
# Step 1600/2000 (80%): TrainTime=00:00:42, Loss=2.190, StepTime=0.024s
# Step 1650/2000 (82%): TrainTime=00:00:43, Loss=2.181, StepTime=0.025s
# Step 1700/2000 (85%): TrainTime=00:00:45, Loss=2.147, StepTime=0.025s
# Step 1750/2000 (88%): TrainTime=00:00:46, Loss=2.168, StepTime=0.024s
# Step 1800/2000 (90%): TrainTime=00:00:47, Loss=2.146, StepTime=0.024s
# Step 1850/2000 (92%): TrainTime=00:00:48, Loss=2.131, StepTime=0.024s
# Step 1900/2000 (95%): TrainTime=00:00:50, Loss=2.103, StepTime=0.025s
# Step 1950/2000 (98%): TrainTime=00:00:51, Loss=2.142, StepTime=0.027s
# Step 2000/2000 (100%): TrainTime=00:00:52, Loss=2.109, StepTime=0.026s
# Validation ---------------------------------------
# Total loss=2.166
#
# RINDY:
# Se romiok thes to thatt patone dvemes omy he thiss you,
# And os, is farid
# Toves Lun dall she trakior a,
# And deth is fided shess bes; I ar.
# 'kice! Coren pix hem; I lor,
# The acert vim, bun o foued
# --------------------------------------------------
# Final generation ------------------------------
#
# My, the be wand ake, the a hand breone,
# Ther Crast bave lof fodaing
# Tenit your it urech'd anw can als fool,
# And froulled.
#
# SARET:
# The I you fo.
#
# Wiven witar ilke I fo tor, alke spoonioug bither re
# seith toure. Cirs rad lomebourste is nos
# Wer tof arde
# hele'st tris titr, why sough fribrst wen sto on om your Sat bereman w'ters;
# Ane so the you r srours
# And wow, winy a expo.
#
# APENUSA:
# But my dikell, ike! nete wrevem erick I Kinoot.
#
# AULANT:
# Noo, athe my pla pupont sprreid vefur it
# er, goor, wholy shar,
# Ansst ro on thisey ur sour yis.
#
# LORTHE:
#
# Set thing awent
# Tom yourgh haverss! thow thousse lord byes up? I cold
# This thim bey ome a willl he fougheress,
# Thalde four fof tominices.
#
#
# POLOM:
# My qus he; fow:
# Nors cof ther pext wist schy brus and hiderjer.
#
# LUMES:
# Go hy diss wook orierce:
# And speatil, cak fa.
#
# Mome cold, whim preey ourns thou'ed arnt
# Auch owef demor, deam'ds, I meip hals oyorsat:
# O ayire he in hin'lem ore pand by iler scald!
# LY Gollfard, ifr.
# Willl she ile illan,
# I his jold omeal

# %%
plot_losses(*train_model(config=mh_config))
# Out:
# Total parameters: 3.80M
# Validation ---------------------------------------
# Total loss=4.288
#
# m:HyP H$!P;CgQP.IPeK?A:.DwVqmm;?w$PUQqqF;M Ben,TWWysNEEK;Dr&jZR&BEGHMcvIGIFxNDNeSnZVtlarMraXv-'WzLaNFVosyT-E-excA?mn?,MiyKjPgDsAolSJeuNCj
# MzwjKqwMRyFlWTCOSwiAlMuFphrZ FexPR&y3Ix-SJrJAeiev&ou vWdVt
# oF-
# --------------------------------------------------
# Step 50/2000 (2%): TrainTime=00:00:08, Loss=2.484, StepTime=0.13s
# Step 100/2000 (5%): TrainTime=00:00:15, Loss=2.459, StepTime=0.14s
# Step 150/2000 (8%): TrainTime=00:00:22, Loss=2.428, StepTime=0.13s
# Step 200/2000 (10%): TrainTime=00:00:28, Loss=2.388, StepTime=0.14s
# Step 250/2000 (12%): TrainTime=00:00:35, Loss=2.300, StepTime=0.13s
# Step 300/2000 (15%): TrainTime=00:00:42, Loss=2.255, StepTime=0.13s
# Step 350/2000 (18%): TrainTime=00:00:49, Loss=2.189, StepTime=0.13s
# Step 400/2000 (20%): TrainTime=00:00:55, Loss=2.174, StepTime=0.13s
# Step 450/2000 (22%): TrainTime=00:01:02, Loss=2.040, StepTime=0.13s
# Step 500/2000 (25%): TrainTime=00:01:09, Loss=1.925, StepTime=0.14s
# Validation ---------------------------------------
# Total loss=1.977
#
# Trass, his gress?
#
# PRIANCE:
# I lead you a breackious ens we ta dearty,
# He my call dietyint, gom; tand hatheathere,
# Tase sm bresty butio, pales all'd borgy
# To deall, your our honfory-brefoty's her.
#
# KIN
# --------------------------------------------------
# Step 550/2000 (28%): TrainTime=00:01:17, Loss=1.824, StepTime=0.14s
# Step 600/2000 (30%): TrainTime=00:01:24, Loss=1.762, StepTime=0.14s
# Step 650/2000 (32%): TrainTime=00:01:31, Loss=1.719, StepTime=0.13s
# Step 700/2000 (35%): TrainTime=00:01:38, Loss=1.677, StepTime=0.13s
# Step 750/2000 (38%): TrainTime=00:01:45, Loss=1.586, StepTime=0.14s
# Step 800/2000 (40%): TrainTime=00:01:51, Loss=1.572, StepTime=0.14s
# Step 850/2000 (42%): TrainTime=00:01:58, Loss=1.528, StepTime=0.13s
# Step 900/2000 (45%): TrainTime=00:02:05, Loss=1.501, StepTime=0.14s
# Step 950/2000 (48%): TrainTime=00:02:12, Loss=1.524, StepTime=0.14s
# Step 1000/2000 (50%): TrainTime=00:02:19, Loss=1.499, StepTime=0.14s
# Validation ---------------------------------------
# Total loss=1.533
#
# vided Pamper, and my soul!
# Be weseech instruments, weap how, sir
# To pleass thunder'd such ase thoril'd;'rate, my baster'd.
# The Rome carry'd, we sets, Claudio, to they queen's with chrefe,
# With necelve
# --------------------------------------------------
# Step 1050/2000 (52%): TrainTime=00:02:28, Loss=1.488, StepTime=0.14s
# Step 1100/2000 (55%): TrainTime=00:02:34, Loss=1.462, StepTime=0.14s
# Step 1150/2000 (57%): TrainTime=00:02:41, Loss=1.451, StepTime=0.14s
# Step 1200/2000 (60%): TrainTime=00:02:48, Loss=1.436, StepTime=0.14s
# Step 1250/2000 (62%): TrainTime=00:02:55, Loss=1.387, StepTime=0.14s
# Step 1300/2000 (65%): TrainTime=00:03:02, Loss=1.390, StepTime=0.14s
# Step 1350/2000 (68%): TrainTime=00:03:09, Loss=1.366, StepTime=0.14s
# Step 1400/2000 (70%): TrainTime=00:03:16, Loss=1.364, StepTime=0.14s
# Step 1450/2000 (72%): TrainTime=00:03:23, Loss=1.339, StepTime=0.14s
# Step 1500/2000 (75%): TrainTime=00:03:29, Loss=1.332, StepTime=0.14s
# Validation ---------------------------------------
# Total loss=1.424
#
# Soft's fortune--Capli, come bride, not therefore,
# Him comforts take with to stake of wit.
#
# KING RICHARD III:
# And as every they moves? O my state Lucentio.
#
# QUEEN ELIZABETH:
# Brother I'll said, it full
# --------------------------------------------------
# Step 1550/2000 (78%): TrainTime=00:03:38, Loss=1.358, StepTime=0.14s
# Step 1600/2000 (80%): TrainTime=00:03:45, Loss=1.323, StepTime=0.14s
# Step 1650/2000 (82%): TrainTime=00:03:52, Loss=1.326, StepTime=0.14s
# Step 1700/2000 (85%): TrainTime=00:03:59, Loss=1.323, StepTime=0.14s
# Step 1750/2000 (88%): TrainTime=00:04:06, Loss=1.313, StepTime=0.14s
# Step 1800/2000 (90%): TrainTime=00:04:13, Loss=1.283, StepTime=0.14s
# Step 1850/2000 (92%): TrainTime=00:04:20, Loss=1.291, StepTime=0.14s
# Step 1900/2000 (95%): TrainTime=00:04:27, Loss=1.285, StepTime=0.14s
# Step 1950/2000 (98%): TrainTime=00:04:34, Loss=1.269, StepTime=0.14s
# Step 2000/2000 (100%): TrainTime=00:04:41, Loss=1.270, StepTime=0.14s
# Validation ---------------------------------------
# Total loss=1.382
#
#
# KING EDWARD IV:
# My sithing lordshoon drums, like his body Play's.
#
# GLOUCESTER:
# Thou shalt be supposed; Or From, methinks:
# Then she darest I am. Licio!
# Cousiner, nor; I love thee; when whence to thee!
# --------------------------------------------------
# Final generation ------------------------------
#
# My to Lord of Nartham,
# That thyself heaven convented of love,
# This paering in mine each in my cannot:
# Too largour I; I have bear our many before.
#
# MENENIUS:
# Then I am now, any most be be but both their fool;
# His nodds thung our to hear some my face.
#
# PROSPETER:
# Why, Warwick, what counsel and I hold mine them;
# Thremse note speak'st, that thou stands and ask,
# With a bawder in gristled doth not as it wine,
# That thy hide I starrow to dispreshly and his part!
# Honest manifest thou keeps to sword;
# On, for, sound! worthy mouth a bainishment-rement
# As thingerwenty govern'gar burried thoughts.
#
# PRINCE:
# Hercus? I call't, some more, see, friend he it blesew.
#
# TRANIO:
# Hush! doth since mistake. Is be serve; forgot
# Sad that he people of Romeo, unnator,
# And here and voice honours woolverant,
# Wenches their face their officer?
# Dear the eyes rush home death.
#
# PRINCE EDWARD:
# And murderous i' to stood talk good heel die?
#
# CLIFFORDENT:
# Now thee and leave son, fair than this words to tale
# Lively wounds of al
