# %% [markdown]
# <a href="https://colab.research.google.com/github/the-mysh/ist-dsl-course/blob/main/src/dsl/hw1_q4_skeleton.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # LLM pretraining

# %% [markdown]
# In this notebook, we will explore the process of pretraining a large language model (LLM) from scratch, focusing on a decoder-only transformer architecture.
#
# The vast majority of current LLMs are trained with a causal auto-regressive objective, where the model predicts the next token given the previous tokens.
#
# We will follow this approach to train a character-level LLM on the works of Shakespeare.

# %%
import dataclasses
import math
import random
import torch
import torch.cuda
import torch.nn as nn
import torch.nn.functional as F
import torch.optim
import torch.utils.data
import time
import matplotlib.pyplot as plt
import numpy as np
from typing import Optional


plt.style.use('seaborn-v0_8')

# %% [markdown]
# ## Part I: The training data

# %% [markdown]
# We will start by preparing the data to train the model, available at [https://raw.githubusercontent.com/karpathy/char-rnn/master/data/tinyshakespeare/input.txt
# ](https://raw.githubusercontent.com/karpathy/char-rnn/master/data/tinyshakespeare/input.txt
# ).
#
# This data was originally used in the following [blog post](https://karpathy.github.io/2015/05/21/rnn-effectiveness/), also worth reading.

# %%
# Downloading the tiny shakespeare dataset
# !wget https://raw.githubusercontent.com/karpathy/char-rnn/master/data/tinyshakespeare/input.txt

# read it in to inspect it
with open('input.txt', 'r', encoding='utf-8') as f:
    text = f.read()

print("Length in characters: ", len(text))

# let's look at the first 100 characters
print("First 100 characters", "-" * 50)
print(text[:100])
# Out:
# --2026-05-15 17:04:46--  https://raw.githubusercontent.com/karpathy/char-rnn/master/data/tinyshakespeare/input.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.110.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1115394 (1.1M) [text/plain]
# Saving to: ‘input.txt.1’
#
# input.txt.1         100%[===================>]   1.06M  --.-KB/s    in 0.03s
#
# 2026-05-15 17:04:46 (34.8 MB/s) - ‘input.txt.1’ saved [1115394/1115394]
#
# Length in characters:  1115394
# First 100 characters --------------------------------------------------
# First Citizen:
# Before we proceed any further, hear me speak.
#
# All:
# Speak, speak.
#
# First Citizen:
# You

# %% [markdown]
# From here, we can create the model vocabulary, which maps the characters into token ids.
#
# We can train the vocabulary on the whole training set and perform some light testing to check that everything is working as expected.

# %%
class Vocabulary:
  """Character-level vocabulary"""

  def __init__(self, text: str):
    """Initialize the vocabulary, mapping individual characters to integers."""
    # We create two dictionaries, ctoi and itoc: the former mapping characters
    # to unique integers and the latter with the reverse mapping.
    chars = set(text)
    self.ctoi = {c: i for i, c in enumerate(chars)}
    self.itoc = {v: k for k, v in self.ctoi.items()}

  def encode(self, text: str) -> list[int]:
    """Encode a string as a list of token ids."""
    return [self.ctoi[t] for t in text]

  def decode(self, ids: list[int]) -> str:
    """Decode a list of token ids into a string."""
    return "".join(self.itoc[i] for i in ids)

  def __len__(self):
    return len(self.ctoi)

  def __str__(self):
    return f"Vocabulary[size={len(self)}]{self.ctoi}"

vocab = Vocabulary(text)
print(vocab)

# Test if encoding/decoding work
first_chars = text[:1000]
encoded = vocab.encode(first_chars)
decoded = vocab.decode(encoded)
assert first_chars == decoded
# Out:
# Vocabulary[size=65]{'!': 0, 'r': 1, 'F': 2, 'C': 3, '.': 4, 'd': 5, 'H': 6, 'l': 7, 'i': 8, 'e': 9, 'Z': 10, 'p': 11, 'u': 12, '\n': 13, 'g': 14, '$': 15, 'y': 16, 'S': 17, 'j': 18, ' ': 19, 'h': 20, 'Y': 21, 'T': 22, 'z': 23, 'n': 24, ':': 25, 'B': 26, 'f': 27, "'": 28, 'U': 29, 'O': 30, 's': 31, 'x': 32, 'q': 33, 'W': 34, 'E': 35, 'X': 36, 'P': 37, 'c': 38, 'o': 39, 'Q': 40, 'm': 41, '&': 42, '3': 43, 'k': 44, 'V': 45, '?': 46, 'b': 47, '-': 48, 'w': 49, ';': 50, 'J': 51, 'M': 52, ',': 53, 'N': 54, 'D': 55, 'R': 56, 't': 57, 'a': 58, 'L': 59, 'I': 60, 'v': 61, 'G': 62, 'K': 63, 'A': 64}

# %% [markdown]
# With our vocabulary, we can encode the full text data as a tensor and split it into data for training and validation.

# %%
# Encode all text
encoded_text = torch.tensor(vocab.encode(text))
print("Total tokens:", encoded_text.size(0))
# Split into train and validation
val_size = 2000

encoded_train = encoded_text[:-val_size]
encoded_val = encoded_text[-val_size:]
print("Train tokens:", encoded_train.size(0))
print("Val tokens: ", encoded_val.size(0))
# Out:
# Total tokens: 1115394
# Train tokens: 1113394
# Val tokens:  2000

# %% [markdown]
# From here, we can create the dataset class to iterate the data. Each record will be a chunk of adjacent tokens and the model will learn to predict the next token from the previous ones.
#
# We will train on sequences of 512 tokens, which offers a good trade-off between previous context length and efficiency (due to the quadractic behavior of attention).

# %%
# Predict on block_size contiguous tokens
seq_len = 512


class ShakespeareDataset(torch.utils.data.Dataset):
  """Dataset class return input and target ids for a given idx"""

  def __init__(self, data: torch.Tensor, seq_len: int):
    self.data = data
    self.seq_len = seq_len


  def __getitem__(self, i: int) -> torch.Tensor:
    """Selects the seq_len+1 tokens starting at index i for training.

    Returns:
        (x, y) tuple, with the input and target ids.
    """
    # Account for extra one in LM offset
    data = self.data[i:i + self.seq_len + 1]
    x = data[:-1]
    y = data[1:]
    return x, y

  def __len__(self):
    """The length of the dataset, only considering complete sequences."""
    return len(self.data) - self.seq_len - 1

train = ShakespeareDataset(encoded_train, seq_len)
val = ShakespeareDataset(encoded_val, seq_len)
print("Train size:", len(train), ", val size:", len(val))
# Out:
# Train size: 1112881 , val size: 1487

# %% [markdown]
# ## Part II: The Transformer Model

# %% [markdown]
# In this section of the notebook, we will implement a standard decoder-only transformer model.
#
# There are many flavours of the transformer architecture, varying all components of the transformer network. In this notebook, we will consider the following configuration:
#
# * **Learnt Positional Encoddings** - In conjuntion with sinosoidal embeddings, these are one of the first approaches for encoding positional information in the transformer architecture, by learning position vectors to encode this information. Currently, however, most transformers adopt [RoPE embeddings](https://arxiv.org/abs/2104.09864).
#
# * **Pre layer normalization** - In contrast with the original transformer, we will add layer normalization *before* the attention and mlp blocks, which is shown to improve performance. Nevertheless, we will adopt the original layer normalization instead of the, nowadays more common, [RMS normalization](https://arxiv.org/abs/1910.07467).
#
# * **MLP with gelu activation** - Following the original transformer, we adopt a two layer MLP, but replace the ReLU activation with [GeLU](https://arxiv.org/abs/1606.08415). Recently, larger models also successfuly adopted variations of [GLUs](https://arxiv.org/abs/2002.05202).
#
# We start by defining the model configuration.

# %%
@dataclasses.dataclass
class Config:
  seq_len: int = seq_len
  n_layers: int = 2
  n_heads: int = 1
  hidden_size: int = 64
  ffn_hidden_size: int = None  # set in __post_init__ if not specified
  head_size: int = None  # as above
  vocab_size: int = len(vocab)
  temperature: float = 1.0

  def __post_init__(self):
    # Using the ffn hidden size as 4 times the
    # network hidden size is a standard value.
    if self.ffn_hidden_size is None:
      self.ffn_hidden_size: int = self.hidden_size * 4

    # Using a head size of hidden_size // n_heads
    # is also a standard approach.
    if self.head_size is None:
      self.head_size = self.hidden_size // self.n_heads

# default configuration
default_config = Config()
print(default_config)
# Out:
# Config(seq_len=512, n_layers=2, n_heads=1, hidden_size=64, ffn_hidden_size=256, head_size=64, vocab_size=65, temperature=1.0)

# %%
# multi-head configuration
mh_config = Config(n_heads=6, hidden_size=384)
print(mh_config)
# Out:
# Config(seq_len=512, n_layers=2, n_heads=6, hidden_size=384, ffn_hidden_size=1536, head_size=64, vocab_size=65, temperature=1.0)

# %% [markdown]
# Afterwards, we will define the self-attention mechanism.

# %%
class SingleHeadAttention(nn.Module):

  def __init__(self, config: Config):
    super().__init__()
    self.config = config
    # As is common in most transformer implementations, we will have single projection
    # matrices to compute queries, keys and values for all heads.
    # As such, each projection matrix will map an input of hidden_size to an output
    # of n_heads * head_size.

    if config.n_heads > 1:
      raise ValueError(f"{self.__class__.__name__} only implements single-head attention; config specifies {config.n_heads} heads")

    self.queries_proj = nn.Linear(config.hidden_size, config.head_size)
    self.keys_proj = nn.Linear(config.hidden_size, config.head_size)
    self.values_proj = nn.Linear(config.hidden_size, config.head_size)
    self.out_proj = nn.Linear(config.head_size, config.hidden_size)

  def forward(self, x: torch.Tensor) -> torch.Tensor:
    # x shape: (batch, seq, hidden)
    B, T, _ = x.size()
    head_dim = self.config.head_size

    # Compute projections and split by queries, keys and values.
    # q, k, v shapes: (batch, seq, head_size).
    q, k, v = self.queries_proj(x), self.keys_proj(x), self.values_proj(x)

    # Isolate heads
    # q, k, v shapes: (batch, seq, head_size)
    q = q.view(B, T, head_dim)
    k = k.view(B, T, head_dim)
    v = v.view(B, T, head_dim)

    # Compute scaled dot product attention.
    # out shape: (batch, seq, head_size)
    scores = (q @ k.transpose(-2, -1)) * (1.0 / math.sqrt(k.size(-1)))
    causal_mask = torch.tril(torch.ones(T, T, device=scores.device))
    causal_mask = causal_mask.view(1, T, T)
    scores = scores.masked_fill(causal_mask == 0, float("-inf"))
    attn = F.softmax(scores, dim=-1)
    out = attn @ v

    # Compute the final projection
    # out shape: (batch, seq, hidden_size)
    out = self.out_proj(out)
    return out

# %%
# Q4.2
class MultiHeadAttention(nn.Module):
  def __init__(self, config: Config):
    super().__init__()
    self.config = config

    # hidden size is expected to be the same as n heads * head size, but in principle could be different
    dim = (config.hidden_size, config.n_heads * config.head_size)
    self.queries_proj = nn.Linear(*dim)
    self.keys_proj = nn.Linear(*dim)
    self.values_proj = nn.Linear(*dim)
    self.out_proj = nn.Linear(*dim[::-1])

  def forward(self, x: torch.Tensor) -> torch.Tensor:
    # x shape: (batch, seq, hidden)
    B, T, _ = x.size()

    # Compute projections and split by queries, keys and values.
    # q, k, v shapes: <batch size, seq length, n heads * head size>
    q, k, v = self.queries_proj(x), self.keys_proj(x), self.values_proj(x)

    # Isolate heads
    # <batch size, seq length, n heads * head size> -> <batch size, seq length, n heads, head size>
    dim = (B, T, self.config.n_heads, self.config.head_size)
    q = q.view(*dim)
    k = k.view(*dim)
    v = v.view(*dim)

    # Transpose to perform multiplications for each head independently
    # (swap seq length and n heads)
    # <batch size, seq length, n heads, head size> -> <batch size, n heads, seq length, head size>
    q = q.transpose(1, 2)
    k = k.transpose(1, 2)
    v = v.transpose(1, 2)

    # Compute scaled dot product attention
    scores = (q @ k.transpose(-2, -1)) * (1.0 / math.sqrt(k.size(-1)))  # -> <batch size, n heads, seq length, seq length>
    causal_mask = torch.tril(torch.ones(T, T, device=scores.device))
    causal_mask = causal_mask.view(1, 1, T, T)  # one more neutral dimension
    scores = scores.masked_fill(causal_mask == 0, float("-inf"))
    attn = F.softmax(scores, dim=-1)
    out = attn @ v  # -> <batch size, n heads, seq length, head size>

    # Concatenate heads
    out = out.transpose(1, 2)  # back to <batch size, seq length, n heads, head size>
    out = out.contiguous().view(B, T, -1)  # -> <batch size, seq length, n heads * head size>

    # Final projection
    out = self.out_proj(out)  # -> <batch size, seq length, hidden size>
    return out

# %% [markdown]
# Second, we will define the MLP layer of the transformer. In our implementation, we will adopt:
# * Up projection layer mapping hidden_size to ffn_hidden_size;
# * Activation function (GeLU);
# * Down projection layer mapping ffn_hidden_size to hidden_size;
# * Dropout.

# %%
class MLP(nn.Module):

  def __init__(self, config: Config):
    super().__init__()
    self.up_proj = nn.Linear(config.hidden_size, config.ffn_hidden_size)
    self.act = nn.GELU()
    self.down_proj = nn.Linear(config.ffn_hidden_size, config.hidden_size)

  def forward(self, x: torch.Tensor) -> torch.Tensor:
    x = self.up_proj(x)
    x = self.act(x)
    x = self.down_proj(x)
    return x

# %% [markdown]
# Now, we will define the transformer block. In contrast with the original transformer implementation, we will apply layer normalization before self-attention and the MLP.

# %%
class Block(nn.Module):

  def __init__(self, config: Config):
    super().__init__()
    attn_class = SingleHeadAttention if config.n_heads == 1 else MultiHeadAttention
    self.attn = attn_class(config)
    self.attn_norm = nn.LayerNorm(config.hidden_size)
    self.mlp = MLP(config)
    self.mlp_norm = nn.LayerNorm(config.hidden_size)

  def forward(self, x: torch.Tensor) -> torch.Tensor:
    h = self.attn_norm(x)
    h = self.attn(h)
    x = x + h
    h = self.mlp_norm(x)
    h = self.mlp(h)
    x = x + h
    return x

# %% [markdown]
# Finally, we will define the transformer decoder, using a causal language modeling objective. For this example, we use learnt embeddings to represent positional information in the transformer.

# %%
class Transformer(nn.Module):

  def __init__(self, config: Config):
    super().__init__()
    # Initialize both embedding layers, one with the size of the vocabulary,
    # and another with the size of the sequence length.
    self.tok_emb = nn.Embedding(config.vocab_size, config.hidden_size)
    self.pos_emb = nn.Embedding(config.seq_len, config.hidden_size)
    # Initialize the transformer blocks
    self.blocks = nn.ModuleList(Block(config) for _ in range(config.n_layers))
    # It is also common to add a final layer norm before the lm_head
    self.final_norm = nn.LayerNorm(config.hidden_size)
    self.lm_head = nn.Linear(config.hidden_size, config.vocab_size, bias=False)

  def forward(
      self,
      inputs: torch.Tensor,
      *,
      labels: Optional[torch.Tensor] = None
  ) -> tuple[torch.Tensor, Optional[torch.Tensor]]:
    """Computes the forward of a transformer model.

    Returns a tuple with two elements. The first is the final logits,
    and the second is the loss (only when labels are provided)
    """
    tok_emb = self.tok_emb(inputs)
    pos_emb = self._get_pos_embeddings(inputs)

    hidden_states = tok_emb + pos_emb

    for block in self.blocks:
      hidden_states = block(hidden_states)

    hidden_states = self.final_norm(hidden_states)
    logits = self.lm_head(hidden_states)

    if labels is None:
      return logits, None

    logits = logits.view(-1, logits.size(-1))
    labels = labels.view(-1)
    loss = F.cross_entropy(logits, labels)
    return logits, loss

  def _get_pos_embeddings(self, tokens: torch.Tensor) -> torch.Tensor:
    """Computes the positional embeddings for the given tokens."""
    batch_size, seq_len = tokens.size()
    pos_idx = torch.arange(seq_len, device=tokens.device)
    pos_emb = self.pos_emb(pos_idx)
    return pos_emb

# %% [markdown]
# ## Part III: Training and Evaluation
#
# In the final part of this notebook, we will implement the training loop, as well as a generation function, and train our transformer.
#
# In order to mitigate expensive cost of training language models, we will implement [mixed precision training](https://arxiv.org/abs/1710.03740). In this approach, while the weights are stored in fp32, the operations inside the model are performed with fp16, levergaging faster gpu implementations.

# %%
def train_step(
    *,
    model: Transformer,
    optimizer: torch.optim.Optimizer,
    scaler: torch.amp.GradScaler,
    device: str,
    x: torch.Tensor,
    y: torch.Tensor,
):
  optimizer.zero_grad()

  # Runs the model in mixed precision, which improves overall speed
  # with minimal performance degradation.
  # https://pytorch.org/docs/stable/notes/amp_examples.html#typical-mixed-precision-training
  with torch.autocast(device_type=device, dtype=torch.float16):
    _, loss = model(x, labels=y)

  scaler.scale(loss).backward()

  scaler.step(optimizer)

  scaler.update()

  return loss.item()

# %%
@torch.no_grad
def validate(
    *,
    model: Transformer,
    val_dataloader: torch.utils.data.DataLoader,
    device: str,
):
    model.eval()
    total_loss = 0.0
    for x, y in val_dataloader:
        x, y = x.to(device), y.to(device)
        with torch.autocast(device_type=device, dtype=torch.float16):
          _, loss = model(x, labels=y)
        total_loss += loss

    total_loss /= len(val_dataloader)

    model.train()
    return total_loss.item()

# %%
@torch.no_grad
def generate(
  model: nn.Module,
  vocab: Vocabulary,
  input: str,
  new_tokens: int,
  device,
  temperature: float = 1.0
):
  model.eval()
  idx = vocab.encode(input)
  idx = torch.tensor(idx, dtype=torch.long, device=device)
  idx = idx.unsqueeze(0)

  for t in range(new_tokens):
    # The model only considers the previous seq len characters.
    ctx = idx[:, -seq_len:]

    with torch.autocast(device_type=device, dtype=torch.float16):
      logits, _ = model(ctx)

    next_logits = logits[:, -1, :]

    if not temperature:
      next_idx = torch.argmax(next_logits, dim=-1)
    else:
      next_logits = next_logits / temperature
      next_probs = torch.softmax(next_logits, dim=-1)
      next_idx = torch.multinomial(next_probs, num_samples=1)

    # append sampled index to the running sequence and continue
    idx = torch.cat((idx, next_idx), dim=1)

  idx = idx.tolist()[0]
  output = vocab.decode(idx)
  model.train()
  return output

# %%
def run_validation(
    *,
    model,
    val_dataloader,
    device,
    val_gen_tokens=100,
    temperature: float = 1.0
    ):

  val_loss = validate(
      model=model,
      val_dataloader=val_dataloader,
      device=device,
  )
  print("Validation", "-" * 39)
  print(f"Total loss={val_loss:.3f}")
  test_input = "\n" # Use new line as if beginning a new paragraph
  test_gen_len = 200
  test_output = generate(
      model,
      vocab,
      test_input,
      test_gen_len,
      device,
      temperature=temperature
  )
  print(test_output)
  print("-" * 50)
  return val_loss

# %%
def set_seed(seed = 42):
  random.seed(seed)
  torch.manual_seed(seed)
  torch.set_float32_matmul_precision("high")

# %%
def train_model(
    *,
    config = Config(),
    num_steps=2000,
    val_every=500,
    log_every=50):

  set_seed()

  device = "cuda" if torch.cuda.is_available() else "cpu"
  if device == "cpu":
    print("WARNING: Using cpu device, training will be slow")

  train_dataloader = torch.utils.data.DataLoader(
      train, batch_size=64, shuffle=True, pin_memory=True, num_workers=2, prefetch_factor=2,
  )
  val_dataloader = torch.utils.data.DataLoader(
      val, batch_size=64, shuffle=False, pin_memory=True, num_workers=2, prefetch_factor=2,
  )

  model = Transformer(config)

  model_params = sum(p.numel() for p in model.parameters())
  print(f"Total parameters: {model_params / 1e6:.2f}M")

  optimizer = torch.optim.AdamW(
      model.parameters(), lr=1e-3, weight_decay=0.1, betas=(0.9, 0.95), fused=True
  )
  scaler = torch.amp.GradScaler()
  model.to(device)

  dataiter = iter(train_dataloader)
  start_time = time.time()
  start_step = time.time()

  train_losses = []
  val_losses = []

  val_losses.append(run_validation(
      model=model,
      val_dataloader=val_dataloader,
      device=device,
  ))

  for step in range(1, num_steps + 1):
    x, y = next(dataiter)
    x, y = x.to(device), y.to(device)
    token_count = x.numel()
    loss = train_step(
        model=model,
        optimizer=optimizer,
        scaler=scaler,
        device=device,
        x=x,
        y=y)

    train_losses.append(loss)

    step_time = time.time() - start_step
    start_step = time.time()
    if step % log_every == 0:
      completed = step / num_steps * 100
      ellapsed = time.time() - start_time
      tok_per_sec = token_count / step_time
      fmt_ellapsed = time.strftime("%H:%M:%S", time.gmtime(ellapsed))
      print(
          f"Step {step}/{num_steps} ({completed:.0f}%): "
          f"TrainTime={fmt_ellapsed}, "
          f"Loss={loss:.3f}, "
          f"StepTime={step_time:.2}s"
      )
    if step % val_every == 0:
      val_losses.append(run_validation(
          model=model,
          val_dataloader=val_dataloader,
          device=device,
          temperature=config.temperature
      ))

  test_input = "\n" # Continue to use new line as if beginning a new paragraph
  test_gen_len = 1000
  test_output = generate(
      model,
      vocab,
      test_input,
      test_gen_len,
      device,
      temperature=config.temperature
  )
  print("Final generation", "-" * 30)
  print(test_output)

  return train_losses, val_losses

# %%
def plot_losses(train_losses, val_losses):
  num_steps = len(train_losses)
  val_every = num_steps // (len(val_losses) - 1)

  fig, ax = plt.subplots(figsize=(12, 5))
  ax.plot(np.arange(num_steps) + 1, train_losses, lw=1.5, label="Training loss")
  ax.plot(np.arange(0, num_steps + 1, val_every) + 1, val_losses, lw=1, ls='--', marker='o', label="Validation loss")
  ax.set_xlabel("Training step")
  ax.set_ylabel("Loss")
  ax.legend()

# %%
t, v = train_model(config=default_config)
plot_losses(t, v)
# Out:
# Total parameters: 0.14M
# Validation ---------------------------------------
# Total loss=4.339
#
# &!ehr$epOTXQAy'dEMxlOjgdLPRJ&&XOoOfDe:qXeNQKmwTHLFgKczYJXS'lBPsQGz;ONfvbt$i:YSYxejPDDya'N't
# q3'TiEcYm,SKeHNz3&TInO&C';YXhJSMHSKjb,-BNtYQW?xoo.VqoNLhi:LH;c-fWjVNVhJakJZmxzM-lhr$UW-B?!jbvZvlIqdvLf,S?bm3
# --------------------------------------------------
# Step 50/2000 (2%): TrainTime=00:00:03, Loss=2.890, StepTime=0.023s
# Step 100/2000 (5%): TrainTime=00:00:04, Loss=2.643, StepTime=0.023s
# Step 150/2000 (8%): TrainTime=00:00:05, Loss=2.545, StepTime=0.024s
# Step 200/2000 (10%): TrainTime=00:00:06, Loss=2.493, StepTime=0.026s
# Step 250/2000 (12%): TrainTime=00:00:08, Loss=2.485, StepTime=0.024s
# Step 300/2000 (15%): TrainTime=00:00:09, Loss=2.487, StepTime=0.024s
# Step 350/2000 (18%): TrainTime=00:00:10, Loss=2.472, StepTime=0.023s
# Step 400/2000 (20%): TrainTime=00:00:11, Loss=2.475, StepTime=0.024s
# Step 450/2000 (22%): TrainTime=00:00:12, Loss=2.458, StepTime=0.024s
# Step 500/2000 (25%): TrainTime=00:00:14, Loss=2.447, StepTime=0.024s
# Validation ---------------------------------------
# Total loss=2.515
#
# ILUCHED:
# I erou, tylllo uthe he futh'l mplle bllourss p y gr mealpet nerer wangu flwhas llllle, a tors we ad tiver nde yorefllehen by?
# Hy ld
# Anenstillithis, Gr handut.
# A:
# F aveperavethe ds l hthacid d
# --------------------------------------------------
# Step 550/2000 (28%): TrainTime=00:00:15, Loss=2.444, StepTime=0.024s
# Step 600/2000 (30%): TrainTime=00:00:17, Loss=2.427, StepTime=0.024s
# Step 650/2000 (32%): TrainTime=00:00:18, Loss=2.446, StepTime=0.026s
# Step 700/2000 (35%): TrainTime=00:00:20, Loss=2.428, StepTime=0.025s
# Step 750/2000 (38%): TrainTime=00:00:21, Loss=2.416, StepTime=0.024s
# Step 800/2000 (40%): TrainTime=00:00:22, Loss=2.394, StepTime=0.024s
# Step 850/2000 (42%): TrainTime=00:00:23, Loss=2.382, StepTime=0.024s
# Step 900/2000 (45%): TrainTime=00:00:24, Loss=2.387, StepTime=0.024s
# Step 950/2000 (48%): TrainTime=00:00:26, Loss=2.365, StepTime=0.024s
# Step 1000/2000 (50%): TrainTime=00:00:27, Loss=2.337, StepTime=0.024s
# Validation ---------------------------------------
# Total loss=2.399
#
# venrendeve stro n towhathtys:
# ot: Wer, cerithieng oof thawon, hesto nghe!
#
# gitequthe lllchoulchas silest'ds, four s ipomps ang,
# Yourd of myoft telatshilerd!
# Tallolt cequthiown mon ionde whakshy, I tun
# --------------------------------------------------
# Step 1050/2000 (52%): TrainTime=00:00:29, Loss=2.332, StepTime=0.024s
# Step 1100/2000 (55%): TrainTime=00:00:30, Loss=2.324, StepTime=0.025s
# Step 1150/2000 (57%): TrainTime=00:00:31, Loss=2.312, StepTime=0.024s
# Step 1200/2000 (60%): TrainTime=00:00:33, Loss=2.305, StepTime=0.025s
# Step 1250/2000 (62%): TrainTime=00:00:34, Loss=2.297, StepTime=0.024s
# Step 1300/2000 (65%): TrainTime=00:00:35, Loss=2.277, StepTime=0.024s
# Step 1350/2000 (68%): TrainTime=00:00:36, Loss=2.253, StepTime=0.024s
# Step 1400/2000 (70%): TrainTime=00:00:38, Loss=2.244, StepTime=0.024s
# Step 1450/2000 (72%): TrainTime=00:00:39, Loss=2.236, StepTime=0.024s
# Step 1500/2000 (75%): TrainTime=00:00:40, Loss=2.228, StepTime=0.024s
# Validation ---------------------------------------
# Total loss=2.267
#
# hirs ton:
# Weneve sing out prollllf, ditcherat, pot hait
# My:
# Lout mayord mis poffenmend ghe, thepme
# sowe mad ithey bleaig chis: he lo jitolpe. chavel the! s thecheveno y gelthibens att had coulates
# Nar
# --------------------------------------------------
# Step 1550/2000 (78%): TrainTime=00:00:42, Loss=2.226, StepTime=0.024s
# Step 1600/2000 (80%): TrainTime=00:00:43, Loss=2.195, StepTime=0.026s
# Step 1650/2000 (82%): TrainTime=00:00:44, Loss=2.197, StepTime=0.024s
# Step 1700/2000 (85%): TrainTime=00:00:46, Loss=2.169, StepTime=0.025s
# Step 1750/2000 (88%): TrainTime=00:00:47, Loss=2.178, StepTime=0.024s
# Step 1800/2000 (90%): TrainTime=00:00:48, Loss=2.155, StepTime=0.024s
# Step 1850/2000 (92%): TrainTime=00:00:49, Loss=2.129, StepTime=0.024s
# Step 1900/2000 (95%): TrainTime=00:00:50, Loss=2.106, StepTime=0.024s
# Step 1950/2000 (98%): TrainTime=00:00:52, Loss=2.141, StepTime=0.024s
# Step 2000/2000 (100%): TrainTime=00:00:53, Loss=2.110, StepTime=0.024s
# Validation ---------------------------------------
# Total loss=2.153
#
# stin icty cownge trof.
# CALES:
# Dou billy thilis hourst wof prunst?
#
# WOThasel wefain: le In for,
# Font wo minck, dearscaigll
# Hatlowne me wingone feaul ofkncest,
# Le:
# CaDa, for, wive den
# out ande, je, mext
# --------------------------------------------------
# Final generation ------------------------------
#
# Nrat devered of rer uee chan.
# The's and pand do sof lomes my deat,
# No jon his prickleese.
#
# Corane te tibe ra Pomelit comp-bow, miber.
#
# EGESTUR:
# Wead amod, theale wales rerd fastince.
#
# EEN:
# Ond prot orkive
# Hige her frupe! rewbedy, foue trmy:
# ly hou his wrow; aney.
#
# QULONTELA:
# Th. lome at o wity ale beenh: le I wifll enly sore,
# I ar saut hol.'s 'that y! Yourelst hiser:
# Ad my wis jor pef this
# Ho math kirelf onstherice,--he lopans ftrequik,
# Wis to to the pin nepo mod, my lout so cxitir besoy swhould.
#
# TROSBENA:
# Costr rentre weas, pance sthang, paw pongh sis the fot lasty teats claris be
# Flls Jand hee the deve: sargles,
# Le, he is myoughrer areit,
# Fo the secos; my cof fupor,
# I Ed'th Lid reputst tach I som qurffos mathy you myou slate ttho a dampl hand,
# Ofe veaios, prir sobur bescame!
# Clisend warrmod de do donett.
# O Sirseent your mome; gever Givelltt.
# This four youn cutt mandokn.
#
# DEEST:
# Hot screr, I rin wince knof suth wourpe sobe;
# Wee your ncop sthe to dof weepacht thund ser,
# Buom.
#
# IEEES I

# %%
plot_losses(*train_model(config=mh_config))
# Out:
# Total parameters: 3.80M
# Validation ---------------------------------------
# Total loss=4.360
#
# &!ehMZ3pkMXQAyMd$MxJOj!dSo,q&&XOopMDyqqmXNZGxCTHLLhKYzzJXS'l.PslGz;eNIv$;$m:YSYx-CP,RV 'N'
# v3uLiE Ym,bKhH3z3x:IjO&COTNWhJ.MASKjbV-BxtYQ.?Nio.JqoNshmVLHQc-oWjVNtmna'PZmx:Mslhr$:3-B'BjxWxvlbtZvLf,R?bm3
# --------------------------------------------------
# Step 50/2000 (2%): TrainTime=00:00:08, Loss=2.483, StepTime=0.13s
# Step 100/2000 (5%): TrainTime=00:00:15, Loss=2.455, StepTime=0.14s
# Step 150/2000 (8%): TrainTime=00:00:22, Loss=2.425, StepTime=0.13s
# Step 200/2000 (10%): TrainTime=00:00:28, Loss=2.374, StepTime=0.13s
# Step 250/2000 (12%): TrainTime=00:00:35, Loss=2.283, StepTime=0.13s
# Step 300/2000 (15%): TrainTime=00:00:42, Loss=2.225, StepTime=0.14s
# Step 350/2000 (18%): TrainTime=00:00:49, Loss=2.128, StepTime=0.14s
# Step 400/2000 (20%): TrainTime=00:00:55, Loss=2.022, StepTime=0.14s
# Step 450/2000 (22%): TrainTime=00:01:02, Loss=1.931, StepTime=0.14s
# Step 500/2000 (25%): TrainTime=00:01:09, Loss=1.846, StepTime=0.14s
# Validation ---------------------------------------
# Total loss=1.876
#
# I'll tom reed succy:
# And the he fath's maste bleatess poopge me: pray'd his and malm:
# Where were too self ady sent ned your loviest
# What me,
# And stall this think brutill rolly:
# And not behus not, ford
# --------------------------------------------------
# Step 550/2000 (28%): TrainTime=00:01:18, Loss=1.753, StepTime=0.14s
# Step 600/2000 (30%): TrainTime=00:01:25, Loss=1.701, StepTime=0.14s
# Step 650/2000 (32%): TrainTime=00:01:32, Loss=1.653, StepTime=0.14s
# Step 700/2000 (35%): TrainTime=00:01:39, Loss=1.608, StepTime=0.14s
# Step 750/2000 (38%): TrainTime=00:01:46, Loss=1.529, StepTime=0.14s
# Step 800/2000 (40%): TrainTime=00:01:53, Loss=1.509, StepTime=0.14s
# Step 850/2000 (42%): TrainTime=00:02:00, Loss=1.482, StepTime=0.14s
# Step 900/2000 (45%): TrainTime=00:02:07, Loss=1.447, StepTime=0.14s
# Step 950/2000 (48%): TrainTime=00:02:14, Loss=1.469, StepTime=0.14s
# Step 1000/2000 (50%): TrainTime=00:02:21, Loss=1.458, StepTime=0.14s
# Validation ---------------------------------------
# Total loss=1.499
#
# ving no pristrience; hath says to her,
# Come young off that what sto of his girled
# My labor sickleps fest in the eye in my hear,
# Your posicy honours, and faith, bold his
# thinks mockins of his honour, a
# --------------------------------------------------
# Step 1050/2000 (52%): TrainTime=00:02:30, Loss=1.440, StepTime=0.14s
# Step 1100/2000 (55%): TrainTime=00:02:37, Loss=1.415, StepTime=0.14s
# Step 1150/2000 (57%): TrainTime=00:02:44, Loss=1.414, StepTime=0.14s
# Step 1200/2000 (60%): TrainTime=00:02:51, Loss=1.403, StepTime=0.14s
# Step 1250/2000 (62%): TrainTime=00:02:58, Loss=1.358, StepTime=0.14s
# Step 1300/2000 (65%): TrainTime=00:03:06, Loss=1.365, StepTime=0.14s
# Step 1350/2000 (68%): TrainTime=00:03:13, Loss=1.339, StepTime=0.15s
# Step 1400/2000 (70%): TrainTime=00:03:20, Loss=1.337, StepTime=0.15s
# Step 1450/2000 (72%): TrainTime=00:03:28, Loss=1.314, StepTime=0.15s
# Step 1500/2000 (75%): TrainTime=00:03:35, Loss=1.314, StepTime=0.14s
# Validation ---------------------------------------
# Total loss=1.428
#
# 'Tis tongues:
# I have more promised, sinces, and out with thy birds
# In prison, your suppose, the mansore made they blest,
# Shall be an accouply city, is this she deving kneel!
# Take hatte, he matter--Nay
# --------------------------------------------------
# Step 1550/2000 (78%): TrainTime=00:03:44, Loss=1.331, StepTime=0.14s
# Step 1600/2000 (80%): TrainTime=00:03:51, Loss=1.302, StepTime=0.14s
# Step 1650/2000 (82%): TrainTime=00:03:58, Loss=1.306, StepTime=0.14s
# Step 1700/2000 (85%): TrainTime=00:04:05, Loss=1.306, StepTime=0.14s
# Step 1750/2000 (88%): TrainTime=00:04:13, Loss=1.296, StepTime=0.14s
# Step 1800/2000 (90%): TrainTime=00:04:20, Loss=1.261, StepTime=0.15s
# Step 1850/2000 (92%): TrainTime=00:04:28, Loss=1.280, StepTime=0.15s
# Step 1900/2000 (95%): TrainTime=00:04:35, Loss=1.274, StepTime=0.16s
# Step 1950/2000 (98%): TrainTime=00:04:44, Loss=1.253, StepTime=0.17s
# Step 2000/2000 (100%): TrainTime=00:04:52, Loss=1.252, StepTime=0.16s
# Validation ---------------------------------------
# Total loss=1.375
#
# I was come to-morrow: I'll prithee, and this, rest,
# Making those of manusice and creative more
# Than was can with't can live to thee from to ear
# Whough; curcient: if so fear with denies
# Tailorize of de
# --------------------------------------------------
# Final generation ------------------------------
#
# Nramper, regnoom even. So have your and patience?
#
# NORTHUMBERLAND:
# Norfolk, blessed Nessinghoon er eventers, Pompey
# Scond you, mistrel
# The same service when thou relembrance as noble
# Of all sweet to Warwick.
#
# BISHOP' calls; be you shall make her looks wrout
# Make alter'd what is thidwining with all be
# hankle anointed with of woding supple hand:
# Alack, from the enough, if I was barren friend
# To have king, nonever it: I have prison
# Is the too, to make no more; and i' the
# Fith, he is tumbloy on of the smalle's porting.
#
# MARCIUS:
# Wedness that's pawn manigory, though cannows and clap,
# The kinsman, where they I them go:
# I'll not to-morrow, and Richard thee crossy
# A creature hape to a ciders.
#
# MISTRANDIO:
# That false this hope counsel, with thy affle.
#
# MARCIUS:
# Sir, I first being so much to bed warrant destray,
# Attemposits to their mother enroof Joliet.
# Take my father curtain to now the house strange;
# Are none numbers for they wisdom Pomforerous.
# Upon my mind: well entire no service,
# That broug

# %%
mh_config_6l = Config(**(dataclasses.asdict(mh_config) | {'n_layers': 6}))
plot_losses(*train_model(config=mh_config_6l))
# Out:
# Total parameters: 10.89M
# Validation ---------------------------------------
# Total loss=4.275
#
# &jehrB$pOMXQBywdEMxlFl!gLxHq&&eOoOBDy$wH'NZGx THLLhPYDzJXS'l:
# seGz;ONfvb;$i:YvYx'Cs,JVVON'v
# BPuLiE Ym,SKpHUz3xTbAO&C'S.WhJjMBS$jbw-BNtYQ.?Nmo.JqoNyhi!LH;c-f:jVNtmjabJZmxzpIlht$:b-BjBjbxxvlbsQNLf,S?bmo
# --------------------------------------------------
# Step 50/2000 (2%): TrainTime=00:00:27, Loss=2.469, StepTime=0.45s
# Step 100/2000 (5%): TrainTime=00:00:50, Loss=2.471, StepTime=0.45s
# Step 150/2000 (8%): TrainTime=00:01:13, Loss=2.397, StepTime=0.46s
# Step 200/2000 (10%): TrainTime=00:01:35, Loss=2.281, StepTime=0.45s
# Step 250/2000 (12%): TrainTime=00:01:58, Loss=2.094, StepTime=0.45s
# Step 300/2000 (15%): TrainTime=00:02:20, Loss=1.910, StepTime=0.46s
# Step 350/2000 (18%): TrainTime=00:02:43, Loss=1.776, StepTime=0.45s
# Step 400/2000 (20%): TrainTime=00:03:05, Loss=1.679, StepTime=0.45s
# Step 450/2000 (22%): TrainTime=00:03:28, Loss=1.584, StepTime=0.46s
# Step 500/2000 (25%): TrainTime=00:03:51, Loss=1.514, StepTime=0.46s
# Validation ---------------------------------------
# Total loss=1.570
#
# My be to reest, your hopeter heaven-dut ply? I have sup;
# Thy peal stinicly, I have will to part!
# Thou with dotse of Petrery? Genemio, and you, thoug
# Fith should a dutle brothers gave thee do his
# A did
# --------------------------------------------------
# Step 550/2000 (28%): TrainTime=00:04:19, Loss=1.502, StepTime=0.45s
# Step 600/2000 (30%): TrainTime=00:04:41, Loss=1.382, StepTime=0.46s
# Step 650/2000 (32%): TrainTime=00:05:04, Loss=1.427, StepTime=0.45s
# Step 700/2000 (35%): TrainTime=00:05:26, Loss=1.369, StepTime=0.45s
# Step 750/2000 (38%): TrainTime=00:05:49, Loss=1.351, StepTime=0.45s
# Step 800/2000 (40%): TrainTime=00:06:12, Loss=1.303, StepTime=0.46s
# Step 850/2000 (42%): TrainTime=00:06:34, Loss=1.287, StepTime=0.45s
# Step 900/2000 (45%): TrainTime=00:06:56, Loss=1.241, StepTime=0.45s
# Step 950/2000 (48%): TrainTime=00:07:19, Loss=1.202, StepTime=0.45s
# Step 1000/2000 (50%): TrainTime=00:07:42, Loss=1.220, StepTime=0.45s
# Validation ---------------------------------------
# Total loss=1.326
#
# vengently astI the visit tyrant, there company
# uple, the worse not your birgutes; he was most has
# Will these for their spent messes well met them castile
# His spoke wheels to home pity: we weshe will n
# --------------------------------------------------
# Step 1050/2000 (52%): TrainTime=00:08:09, Loss=1.205, StepTime=0.45s
# Step 1100/2000 (55%): TrainTime=00:08:32, Loss=1.167, StepTime=0.46s
# Step 1150/2000 (57%): TrainTime=00:08:55, Loss=1.166, StepTime=0.46s
# Step 1200/2000 (60%): TrainTime=00:09:18, Loss=1.132, StepTime=0.46s
# Step 1250/2000 (62%): TrainTime=00:09:41, Loss=1.093, StepTime=0.46s
# Step 1300/2000 (65%): TrainTime=00:10:04, Loss=1.061, StepTime=0.45s
# Step 1350/2000 (68%): TrainTime=00:10:26, Loss=1.052, StepTime=0.45s
# Step 1400/2000 (70%): TrainTime=00:10:49, Loss=1.020, StepTime=0.45s
# Step 1450/2000 (72%): TrainTime=00:11:12, Loss=0.991, StepTime=0.46s
# Step 1500/2000 (75%): TrainTime=00:11:35, Loss=0.968, StepTime=0.46s
# Validation ---------------------------------------
# Total loss=1.421
#
#
# MONTAGUE:
# Yet.
#
# BRAKENBURY:
# Tut, sweet Bona, we'll appear to the market;
# And your graced in love,
# So look on you beg'd, by your virtue mine.
#
# KING RICHARD III:
# Speak you, God frame to you, Sir Jord O
# --------------------------------------------------
# Step 1550/2000 (78%): TrainTime=00:12:03, Loss=0.954, StepTime=0.46s
# Step 1600/2000 (80%): TrainTime=00:12:26, Loss=0.943, StepTime=0.46s
# Step 1650/2000 (82%): TrainTime=00:12:49, Loss=0.858, StepTime=0.46s
# Step 1700/2000 (85%): TrainTime=00:13:12, Loss=0.879, StepTime=0.46s
# Step 1750/2000 (88%): TrainTime=00:13:35, Loss=0.833, StepTime=0.46s
# Step 1800/2000 (90%): TrainTime=00:13:57, Loss=0.818, StepTime=0.45s
# Step 1850/2000 (92%): TrainTime=00:14:20, Loss=0.800, StepTime=0.46s
# Step 1900/2000 (95%): TrainTime=00:14:43, Loss=0.753, StepTime=0.46s
# Step 1950/2000 (98%): TrainTime=00:15:06, Loss=0.692, StepTime=0.45s
# Step 2000/2000 (100%): TrainTime=00:15:29, Loss=0.666, StepTime=0.46s
# Validation ---------------------------------------
# Total loss=1.707
#
# I take the poisoner of Corioli,
# It is yet dealth by my life, never beauty's wife
# Where that slander's necessity.
#
# MIRANDA:
# Then,
# Aster these monary I
#
# There stood by? Say it before a groaning: but, fe
# --------------------------------------------------
# Final generation ------------------------------
#
# No, less it not resort to her only bed,
# And her made a bite must be all her boot.
# No ever George, hence, is no longer cannot speak?
# O honest shall purchase I have turn'd in land--
# With too much she's with windows' for breath,
# Nor for Cices: let I would post this day,
# Those sword as what thou yet be perfected.
# He'll then, 'tis dingred the heart'st thou forth,
# I have more matrows. Come, come, Harry, kill'd
# Borohehead, hell's bilteren the towns on you;
# I have thrust caught the hexttiruments on my taughts,
# For person me to myself.
#
# VIRGILIA:
# O, do you look'd and have stay'd you leave to hear
# And where you'll tall good me your witshool.
# I'll be at the tied feeling: I was it I give
# For I shall deaper it, and farewell to be my
# Remain with that.
#
# VALERIA:
# Lend thy soul rust; as I came from the Tower.
# Once more, I see, if you will come to your back.
#
# VALTINE:
# Ay, any thing to give that.
#
# GEVRGARUM:
# What, arting amazed; therefore comes not I thine.
#
# VINCENTIO:
# Good father, go before thy horse: I

# %%
mh_config_low_temp = Config(**(dataclasses.asdict(mh_config) | {'temperature': 0.1}))
plot_losses(*train_model(config=mh_config_low_temp))
# Out:
# Total parameters: 3.80M
# Validation ---------------------------------------
# Total loss=4.360
#
# &!ehMZ3pkMXQAyMd$MxJOj!dSo,q&&XOopMDyqqmXNZGxCTHLLhKYzzJXS'l.PslGz;eNIv$;$m:YSYx-CP,RV 'N'
# v3uLiE Ym,bKhH3z3x:IjO&COTNWhJ.MASKjbV-BxtYQ.?Nio.JqoNshmVLHQc-oWjVNtmna'PZmx:Mslhr$:3-B'BjxWxvlbtZvLf,R?bm3
# --------------------------------------------------
# Step 50/2000 (2%): TrainTime=00:00:09, Loss=2.483, StepTime=0.16s
# Step 100/2000 (5%): TrainTime=00:00:17, Loss=2.455, StepTime=0.16s
# Step 150/2000 (8%): TrainTime=00:00:25, Loss=2.425, StepTime=0.16s
# Step 200/2000 (10%): TrainTime=00:00:34, Loss=2.374, StepTime=0.16s
# Step 250/2000 (12%): TrainTime=00:00:42, Loss=2.283, StepTime=0.16s
# Step 300/2000 (15%): TrainTime=00:00:50, Loss=2.225, StepTime=0.16s
# Step 350/2000 (18%): TrainTime=00:00:57, Loss=2.128, StepTime=0.15s
# Step 400/2000 (20%): TrainTime=00:01:05, Loss=2.022, StepTime=0.15s
# Step 450/2000 (22%): TrainTime=00:01:13, Loss=1.931, StepTime=0.15s
# Step 500/2000 (25%): TrainTime=00:01:20, Loss=1.846, StepTime=0.15s
# Validation ---------------------------------------
# Total loss=1.876
#
# The shall the so the so the so his the so his the strust
# The shall the shall the so the stall the so stand the sould
# The so so he the so he the hath should the stand the be sone
# And the shall the so h
# --------------------------------------------------
# Step 550/2000 (28%): TrainTime=00:01:30, Loss=1.753, StepTime=0.15s
# Step 600/2000 (30%): TrainTime=00:01:38, Loss=1.701, StepTime=0.16s
# Step 650/2000 (32%): TrainTime=00:01:46, Loss=1.653, StepTime=0.16s
# Step 700/2000 (35%): TrainTime=00:01:54, Loss=1.608, StepTime=0.16s
# Step 750/2000 (38%): TrainTime=00:02:01, Loss=1.529, StepTime=0.16s
# Step 800/2000 (40%): TrainTime=00:02:09, Loss=1.509, StepTime=0.16s
# Step 850/2000 (42%): TrainTime=00:02:17, Loss=1.482, StepTime=0.16s
# Step 900/2000 (45%): TrainTime=00:02:25, Loss=1.447, StepTime=0.16s
# Step 950/2000 (48%): TrainTime=00:02:33, Loss=1.469, StepTime=0.15s
# Step 1000/2000 (50%): TrainTime=00:02:40, Loss=1.458, StepTime=0.16s
# Validation ---------------------------------------
# Total loss=1.499
#
# And the prince the comes to the come to the death,
# And the see the words and the duke and the stands,
# And so shall be the rest the courselves of the prince,
# That the seem that thou have the shall be t
# --------------------------------------------------
# Step 1050/2000 (52%): TrainTime=00:02:50, Loss=1.440, StepTime=0.16s
# Step 1100/2000 (55%): TrainTime=00:02:58, Loss=1.415, StepTime=0.16s
# Step 1150/2000 (57%): TrainTime=00:03:06, Loss=1.414, StepTime=0.16s
# Step 1200/2000 (60%): TrainTime=00:03:13, Loss=1.403, StepTime=0.16s
# Step 1250/2000 (62%): TrainTime=00:03:21, Loss=1.358, StepTime=0.15s
# Step 1300/2000 (65%): TrainTime=00:03:29, Loss=1.365, StepTime=0.16s
# Step 1350/2000 (68%): TrainTime=00:03:37, Loss=1.339, StepTime=0.15s
# Step 1400/2000 (70%): TrainTime=00:03:45, Loss=1.337, StepTime=0.15s
# Step 1450/2000 (72%): TrainTime=00:03:52, Loss=1.314, StepTime=0.16s
# Step 1500/2000 (75%): TrainTime=00:04:00, Loss=1.314, StepTime=0.15s
# Validation ---------------------------------------
# Total loss=1.428
#
# And the courted the seem the countent the can thee,
# That the consent the countent the countented the courtesy
# That the seen the countent to the commanded
# The sea the crown the counsel the courtesy
# Tha
# --------------------------------------------------
# Step 1550/2000 (78%): TrainTime=00:04:10, Loss=1.331, StepTime=0.15s
# Step 1600/2000 (80%): TrainTime=00:04:18, Loss=1.302, StepTime=0.16s
# Step 1650/2000 (82%): TrainTime=00:04:26, Loss=1.306, StepTime=0.16s
# Step 1700/2000 (85%): TrainTime=00:04:34, Loss=1.306, StepTime=0.16s
# Step 1750/2000 (88%): TrainTime=00:04:41, Loss=1.296, StepTime=0.15s
# Step 1800/2000 (90%): TrainTime=00:04:49, Loss=1.261, StepTime=0.16s
# Step 1850/2000 (92%): TrainTime=00:04:57, Loss=1.280, StepTime=0.15s
# Step 1900/2000 (95%): TrainTime=00:05:05, Loss=1.274, StepTime=0.16s
# Step 1950/2000 (98%): TrainTime=00:05:13, Loss=1.253, StepTime=0.16s
# Step 2000/2000 (100%): TrainTime=00:05:20, Loss=1.252, StepTime=0.16s
# Validation ---------------------------------------
# Total loss=1.375
#
#
# SICINIUS:
# I will thee thee to the prison of the people.
#
# CORIOLANUS:
# I think thee the prince, that the content the people
# The strength of the death.
#
# MERCUTIO:
# The shall be so the duke the thine ears
# --------------------------------------------------
# Final generation ------------------------------
#
#
# Second Servingman:
# Not a service the strength of the princely show
# That he shall be so her and the people,
# That we have some strange the senate the store,
# That the sentence that the sentence the sentence
# Than the sentence the present to the prince
# That the strength of the prince of his part
# Than the precious that the stream of the strength,
# The stream the strength of the secret the strength
# That the sea the precious the strength of the country
# With the senators the sea the sea the both of his son,
# That the son the strength and the state the sear
# The shall be the son the strength of the sears,
# That the shall be the son of the shame to the priest
# Than the seat the son of the thought the state,
# And then the shall be the son the seat of the sear
# The shall be the precious should shall be so down.
#
# First Servingman:
# What they shall be the thought the contented
# The strength of the people the sun of the search
# Than the seat the shall be the son of the search of
# The shapes the sea the sea the
